# %% [markdown]
# <center><h2>Introduction to Machine Learning</h2></center>
#
# <center><img src="images/robot.png" width="55%"/></center>

# %% [markdown]
# By The End Of This Session You Should Be Able To:
# ----
#
# - Define Machine Learning
# - Explain the difference between Statistics, Artificial Intelligence, and Machine Learning
# - List the steps in the Data Science Workflow

# %% [markdown]
# What is Machine Learning?
# -----
#
# Think, Pair, & Share

# %% [markdown]
# I'm going to present different viewpoints so you can form your own definition.

# %% [markdown]
# What is the difference between Statistics and Machine Learning?
# ------

# %% [markdown]
# 1) About $45,000 a year in salary

# %% [markdown]
# 2) Statistics is a subfield of mathematics, thus more theoretical.
#
# Machine Learning is a subfield of computer science and artificial intelligence, thus more applied.

# %% [markdown]
# 3) Not much. They are both concerned with the same question:
# <br>
# <br>
# __How do we learn from data?__

# %% [markdown]
# 4) Stats focuses on the formalization of relationships between variables in the form of mathematical equations.
#
# ML focuses on coding systems that can learn from data, instead of explicitly programmed instructions.

# %% [markdown]
# A Tale of Two Cultures
# ------
#
# 1. Data Modeling
# 1. Algorithmic Modeling

# %% [markdown]
# Source: Statistical Modeling: The Two Cultures by Leo Breiman

# %% [markdown]
# The Data Modeling Culture: Statistics
# -------
#
# <center><img src="images/model.png" width="75%"/></center>
#
# 1. Data are generated by independent draws (i.i.d.)
# 1. Values of the parameters are estimated from the data
# 1. Model then used for information and/or prediction

# %% [markdown]
# The Algorithmic Modeling Culture: ML
# -------
#
# <center><img src="images/algo.png" width="75%"/></center>
#
# 1. Find a function f(x) - an algorithm that operates on x to predict the responses y
# 1. Does not matter how data are generated
# 1. Only care about prediction. Informative models are just a step along the way

# %% [markdown]
# What is the difference between ML & CS?
# ----

# %% [markdown]
# - ML is data up. CS is logic down.
# - ML is probabilistic. CS is deterministic.

# %% [markdown]
# What is the difference between ML & AI?
# ----
#
# <center><img src="images/ai.png" width="95%"/></center>

# %% [markdown]
# What is the relationship between Artificial Intelligence, Machine Learning, and Deep Learning?
# -------
#
# <center><img src="https://www.bing.com/th?id=OIP.GDp24Tu2sZu1khv0YXTligHaHX&pid=Api" width="500"/></center>

# %% [markdown]
# Goals of AI
# -----
#
# 1. Systems that think like humans
# 2. Systems that act like humans
# 3. Systems that think optimally
# 4. Systems that act optimally

# %% [markdown]
# Data Science Workflow
# ----
# <center><img src="images/step.png" width="90%"/></center>

# %% [markdown]
# Data Science Workflow
# ----
# 1. Ask
# 2. Acquire
# 3. Process
# 4. Model
# 5. Deliver

# %% [markdown]
# Let's apply the Data Science Workflow
# -------
#
# Who has a practicum project?

# %% [markdown]
# Who has a practicum takehome assignment?

# %% [markdown]
# 1) Ask
# ----
#
# Starting with domain experience, ask specific and meaningful questions.
#
# Define all terms precisely withing the context.

# %% [markdown]
# 2) Acquire
# ----
#
# Do I have even have access to the relevant data?
#
# How is the data stored?
#
# Is the organization even collecting the right data?

# %% [markdown]
# 3) Process
# ------
#
# Get all the data in a single location. Machine Learning needs to have in one place, usually a single Data Frame
#
# Understand, organize, munge, and clean
#
# Find labels to answer questions

# %% [markdown]
# 4) Model
# ------
#
# Apply Statistics, Machine Learning, and Deep Learning algorithms

# %% [markdown]
# <center><img src="images/linear_regression.png" width="75%"/></center>
#
# Modeling is not actually that important - Any model will be good enough for most applied settings.

# %% [markdown]
# 5) Deliver
# -----
#
# The goal is to add value.

# %% [markdown]
# Is it a report, presentation, or code?
#
# How are the models going into production? Raw code? PMML? API?
#
# What does the system look like when the data changes?

# %% [markdown]
# <center><img src="images/data_science_workflow.png" width="90%"/></center>

# %% [markdown]
# <center><img src="images/hiarchacy.png" width="90%"/></center>

# %% [markdown]
# Why the heck do we even have this class? <br> Isn't everything DL?
# ------

# %% [markdown]
#  1. Fundamentals never change
#  1. Deep Learning is a only applicable for a limited subset of problems
#      1. Requires lots of compute
#      1. Requires lots of data

# %% [markdown]
# The world is long-tailed
# -----
# <center><img src="images/deep.png" width="70%"/></center>

# %% [markdown]
# In terms of deep learning, it’s accepted that DL models require 106 as a minimum size for training datasets. The excellent paper “The Devil is in the Tails: Fine-grained Classification in the Wild” by Grant Van Horn, Pietro Perona / CalTech (2017-09-05) explores quantitative relationships between size of training data, number of classes, and model error rates (h/t JK):
#
# “The number of training images is critical: classification error more than doubles every time we cut the number of training images by a factor of 10. This is particularly important in a long-tailed regime since the tails contain most of the categories and therefore dominate average classification performance.”
#
# Van Horn and Perona open with a brilliant one-liner: the world is long-tailed. The diagram above shows analysis from Deep Learning Analytics, the #2 team placing in the iNaturalist 2018 competition. Part of that challenge was how many of the classes to be learned had few data points for training. That condition is much more “real world” than the famed ImageNet – with an average of ~500 instances per class – which helped make “deep learning” a popular phrase.  The aforementioned sea change from Lange, Jonas, et al., addresses the problem of reducing data demands. I can make an educated guess that your enterprise ML use cases resemble iNaturalist more than ImageNet, and we need to find ways to produce effective models which don’t require enormous labeled data sets.

# %% [markdown]
# What is Machine Learning?
# -----

# %% [markdown]
# <h2><center>Learn a function from data that can generalize to predict new data.</center></h2>

# %% [markdown]
# Summary
# ------
#
# - Machine Learning is a field of study with roots in CS, thus focuses on solving applied problems with code
# - Machine Learning only cares about prediction
# - Apply the Data Science Workflow
#     1. Ask
#     2. Acquire
#     3. Process
#     4. Model
#     5. Deliver
# - Machine Learning is a small part of Data Science

# %% [markdown]
# <br>
